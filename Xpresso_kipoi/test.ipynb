# %%
# Imports
import kipoi
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ### Source Model

# %%
# Source model directly from directory
model = kipoi.get_model("../Xpresso_kipoi/human_median", source="dir")
# Out:
# 0.00B [00:00, ?B/s]
# Downloading https://zenodo.org/record/4075690/files/humanMedian_trainepoch.11-0.426.h5 to /data/nasif12/home_if12/karollus/5UTRModel/xpresso/Xpresso_kipoi/Xpresso_kipoi/downloaded/model_files/human_median/weights/9d00a3bc614da81655328b6e278569e2
# 1.39MB [00:00, 1.84MB/s]
# WARNING:tensorflow:From /opt/modules/i12g/anaconda/envs/kipoi-Framepool2/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/modules/i12g/anaconda/envs/kipoi-Framepool2/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /opt/modules/i12g/anaconda/envs/kipoi-Framepool2/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/modules/i12g/anaconda/envs/kipoi-Framepool2/lib/python3.6/site-packages/keras/engine/saving.py:327: UserWarning: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
#   warnings.warn('Error in loading the saved optimizer '

# %% [markdown]
# ### Download and prepare example files (optional)

# %%
import urllib.request
import gzip
import shutil
import pyranges as pr

# %%
# make ExampleFile directory if it does not exist
if not os.path.exists("ExampleFiles"):
    os.makedirs("ExampleFiles")

# %%
# Download GTF
urllib.request.urlretrieve("https://zenodo.org/record/1466102/files/example_files-gencode.v24.annotation_chr22.gtf?download=1", 'ExampleFiles/chrom22.gtf')
# Download fasta
urllib.request.urlretrieve("https://zenodo.org/record/1466102/files/example_files-hg38_chr22.fa?download=1", 'ExampleFiles/chrom22.fa')
# Out:
# ('ExampleFiles/chrom22.fa', <http.client.HTTPMessage at 0x2b89ab7aefd0>)

# %%
# Extract implied TSS sites from gtf
# Read in with pyranges
gr = pr.read_gtf('ExampleFiles/chrom22.gtf')
# Extract protein coding genes
prot_genes = gr.df[(gr.df.Feature == 'gene') & (gr.df.gene_type == 'protein_coding')]
# Compute implied TSS
prot_genes['TSS'] = (prot_genes.Start * (prot_genes.Strand == "+")) + (prot_genes.End * (prot_genes.Strand == "-"))
# Determine region around TSS
prot_genes['region_start'] = prot_genes.TSS + (-7000*(prot_genes.Strand == "+")) + (-3500 * (prot_genes.Strand == "-"))
prot_genes['region_end'] = prot_genes.TSS + (3500*(prot_genes.Strand == "+")) + (7000 * (prot_genes.Strand == "-"))
# Add nuisance column to make bed6
prot_genes["score"] = "."

# %%
# write bed file
bed = prot_genes[['Chromosome', 'region_start', 'region_end', 'gene_id', 'score', 'Strand']]
bed.to_csv("ExampleFiles/chrom22.bed", sep='\t', header=False, index=False)

# %% [markdown]
# ### Provide the Parameters

# %%
# Path of the fasta file
fasta_path = "ExampleFiles/chrom22.fa"
# Set false if fasta has a chr prefix, true otherwise
num_chr = False

# Path of the bed file specifying the promoter regions
bed_path = "ExampleFiles/chrom22.bed"

# output file path
output_file_path = "predictions.tsv"

# %% [markdown]
# ### Run Prediction

# %%
model.pipeline.predict_to_file(output_file_path, {"intervals_file":bed_path, 
                               "fasta_file":fasta_path,
                               "num_chr_fasta":num_chr},
                              batch_size=64)
# Out:
# 100%|██████████| 7/7 [00:16<00:00,  2.42s/it]

# %% [markdown]
# ### Load results

# %%
# Load data as dataframe
df = pd.read_csv(output_file_path, sep="\t")
df
# Out:
#     metadata/ranges/chr  metadata/ranges/end  metadata/ranges/id  \
# 0                 chr22             11070000                   0
# 1                 chr22             15531657                   1
# 2                 chr22             15693525                   2
# 3                 chr22             17088453                   3
# 4                 chr22             17363448                   4
# ..                  ...                  ...                 ...
# 434               chr22             50585465                 434
# 435               chr22             50589965                 435
# 436               chr22             50608455                 436
# 437               chr22             50635173                 437
# 438               chr22             50790663                 438
#
#      metadata/ranges/start metadata/ranges/strand  preds/expression_pred
# 0                 11059500                      +              -0.097702
# 1                 15521157                      +              -1.052358
# 2                 15683025                      +              -0.806651
# 3                 17077953                      +               0.872204
# 4                 17352948                      +              -0.903286
# ..                     ...                    ...                    ...
# 434               50574965                      -               0.178786
# 435               50579465                      -               0.955409
# 436               50597955                      -              -0.159009
# 437               50624673                      -               0.754210
# 438               50780163                      -               0.078148
#
# [439 rows x 6 columns]

# %%
# Merge back with gene_ids
df = df.rename(columns={"metadata/ranges/chr":"Chromosome", "metadata/ranges/start":"region_start", "metadata/ranges/end":"region_end", "metadata/ranges/strand":"strand"})
merged = prot_genes.merge(df, on=["Chromosome", "region_start", "region_end"])

# %%
merged
# Out:
#     Chromosome   Source Feature     Start       End Score Strand Frame  \
# 0        chr22  ENSEMBL    gene  11066500  11068089     .      +     .
# 1        chr22   HAVANA    gene  15528157  15529139     .      +     .
# 2        chr22   HAVANA    gene  15690025  15721631     .      +     .
# 3        chr22   HAVANA    gene  17084953  17115694     .      +     .
# 4        chr22   HAVANA    gene  17359948  17558149     .      +     .
# ..         ...      ...     ...       ...       ...   ...    ...   ...
# 434      chr22   HAVANA    gene  50568860  50578465     .      -     .
# 435      chr22   HAVANA    gene  50568868  50582965     .      -     .
# 436      chr22   HAVANA    gene  50578948  50601455     .      -     .
# 437      chr22   HAVANA    gene  50622753  50628173     .      -     .
# 438      chr22   HAVANA    gene  50767500  50783663     .      -     .
#
#                 gene_id       gene_type  ... havana_transcript protein_id  \
# 0     ENSG00000279973.1  protein_coding  ...               NaN        NaN
# 1     ENSG00000130538.4  protein_coding  ...               NaN        NaN
# 2    ENSG00000198062.14  protein_coding  ...               NaN        NaN
# 3    ENSG00000177663.13  protein_coding  ...               NaN        NaN
# 4    ENSG00000099954.18  protein_coding  ...               NaN        NaN
# ..                  ...             ...  ...               ...        ...
# 434  ENSG00000205560.12  protein_coding  ...               NaN        NaN
# 435   ENSG00000254413.8  protein_coding  ...               NaN        NaN
# 436  ENSG00000100288.19  protein_coding  ...               NaN        NaN
# 437  ENSG00000100299.17  protein_coding  ...               NaN        NaN
# 438  ENSG00000079974.17  protein_coding  ...               NaN        NaN
#
#     ccdsid       TSS region_start region_end score metadata/ranges/id strand  \
# 0      NaN  11066500     11059500   11070000     .                  0      +
# 1      NaN  15528157     15521157   15531657     .                  1      +
# 2      NaN  15690025     15683025   15693525     .                  2      +
# 3      NaN  17084953     17077953   17088453     .                  3      +
# 4      NaN  17359948     17352948   17363448     .                  4      +
# ..     ...       ...          ...        ...   ...                ...    ...
# 434    NaN  50578465     50574965   50585465     .                434      -
# 435    NaN  50582965     50579465   50589965     .                435      -
# 436    NaN  50601455     50597955   50608455     .                436      -
# 437    NaN  50628173     50624673   50635173     .                437      -
# 438    NaN  50783663     50780163   50790663     .                438      -
#
#     preds/expression_pred
# 0               -0.097702
# 1               -1.052358
# 2               -0.806651
# 3                0.872204
# 4               -0.903286
# ..                    ...
# 434              0.178786
# 435              0.955409
# 436             -0.159009
# 437              0.754210
# 438              0.078148
#
# [439 rows x 33 columns]
